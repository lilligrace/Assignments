# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
airlines=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airlines.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airlines[airlines.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %%
airlines=airlines.drop(['ID#','Award?'],axis=1)
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
transformation=MinMaxScaler()
airlines1=pd.DataFrame(transformation.fit_transform(airlines.iloc[:,0:]))
airlines1
# Out:
#              0    1     2    3    4         5         6         7         8  \
# 0     0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000  0.000000
# 1     0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000  0.000000
# 2     0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000  0.000000
# 3     0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000  0.000000
# 4     0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398  0.075472
# ...        ...  ...   ...  ...  ...       ...       ...       ...       ...
# 3994  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490  0.018868
# 3995  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000  0.000000
# 3996  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000  0.000000
# 3997  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225  0.018868
# 3998  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#              9
# 0     0.843742
# 1     0.839884
# ...

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
a=linkage(airlines1,method='average',metric='euclidean')
plt.figure(figsize=(15,5))
plt.title("Hierachinal clustering Dendrogram")
plt.xlabel("index")
plt.ylabel("distance")
sch.dendrogram(a)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import warnings
warnings.filterwarnings('ignore')
H_complete=AgglomerativeClustering(n_clusters=4, linkage="average",affinity="euclidean").fit(airlines1)
cluster_labels=pd.Series(H_complete.labels_)
cluster_labels
airlines['clust']=cluster_labels
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines.iloc[:,1:].groupby(airlines.clust).mean()
# Out:
#        Qual_miles  cc1_miles  cc2_miles  cc3_miles    Bonus_miles  \
# clust
# 0      141.044844   2.030656   1.014695   1.000760   16030.624778
# 1       78.800000   3.466667   1.000000   4.066667   93927.866667
# 2      512.228571   4.771429   1.000000   1.000000  108066.600000
# 3      250.000000   1.000000   1.000000   1.000000   49057.500000
#
#        Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# clust
# 0        11.270585         408.284773         1.220674        4099.240942
# 1        28.066667         506.666667         1.600000        4613.866667
# 2        38.457143        5056.371429        15.571429        6216.057143
# 3        72.000000       21845.000000        53.000000        1822.500000
#
#        clust
# clust
# 0        0.0
# 1        1.0
# 2        2.0
# 3        3.0

# %%
airlines2=airlines[(airlines.clust==0)]
airlines2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines3=airlines[(airlines.clust==1)]
airlines3
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 106     96627        1182          1          1          3        49059
# 384     28193           0          5          1          4       103456
# 850     25629           0          4          1          5       107308
# 904     15835           0          2          1          5       112171
# 1036   154664           0          4          1          3        73881
# 1244   166465           0          4          1          4        98717
# 1300   737514           0          3          1          4        43993
# 1878   128302           0          5          1          4       132263
# 1917    82981           0          5          1          3       105325
# 1946   126873           0          4          1          5        95598
# 2251   125679           0          3          1          4        68151
# 2283   128456           0          5          1          3        70125
# ...

# %%
airlines4=airlines[(airlines.clust==3)]
airlines4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3235   287033           0          1          1          1        26161
# 3583   160114         500          1          1          1        71954
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
#
#       clust
# 3235      3
# 3583      3

# %%
import sklearn
sklearn.metrics.silhouette_score(airlines1,H_complete.labels_)
# Out:
# 0.4165901916058432

# %%
from sklearn.cluster import KMeans
fig = plt.figure(figsize=(10, 8))
WCSS = []
for i in range(1, 11):
    clf = KMeans(n_clusters=i)
    clf.fit(airlines1)
    WCSS.append(clf.inertia_) 
plt.plot(range(1, 11), WCSS)
plt.title('The Elbow Method')
plt.ylabel('WCSS')
plt.xlabel('Number of Clusters')
plt.show()

# %%
clf = KMeans(n_clusters=4)
y_kmeans = clf.fit_predict(airlines1)

# %%
y_kmeans
clf.labels_
# Out:
# array([2, 2, 2, ..., 1, 0, 0])

# %%
y_kmeans
# Out:
# array([2, 2, 2, ..., 1, 0, 0])

# %%
clf.cluster_centers_
# Out:
# array([[2.36724363e-02, 1.09788344e-02, 2.37926136e-02, 1.10085227e-02,
#         1.24289773e-03, 1.69214392e-02, 8.35177722e-02, 1.28437586e-02,
#         2.19500429e-02, 2.65314415e-01],
#        [5.01893530e-02, 1.09101606e-02, 6.26102941e-01, 7.35294118e-04,
#         3.30882353e-03, 1.18152084e-01, 2.09917921e-01, 1.28678021e-02,
#         2.18091010e-02, 3.63864204e-01],
#        [3.87082781e-02, 1.52707004e-02, 3.21888412e-02, 1.07296137e-02,
#         1.50214592e-03, 1.96348371e-02, 9.29234455e-02, 1.58009047e-02,
#         2.81156369e-02, 6.93991623e-01],
#        [8.05499702e-02, 1.47843877e-02, 7.54021448e-01, 6.70241287e-04,
#         8.71313673e-03, 1.78247067e-01, 2.29082237e-01, 1.93799495e-02,
#         3.37144013e-02, 7.44413255e-01]])

# %%
clf.inertia_
# Out:
# 272.39276621164294

# %%
md=pd.Series(y_kmeans) 
airlines['clust']=md 
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines.iloc[:,1:].groupby(airlines.clust).mean()
# Out:
#        Qual_miles  cc1_miles  cc2_miles  cc3_miles   Bonus_miles  Bonus_trans  \
# clust
# 0      122.392045   1.095170   1.022017   1.004972   4461.929688     7.182528
# 1      121.805596   3.503682   1.001473   1.013255  31160.790869    18.055965
# 2      170.237768   1.128755   1.021459   1.006009   5177.412017     7.991416
# 3      164.595716   4.016064   1.001339   1.034806  46974.539491    19.696118
#
#        Flight_miles_12mo  Flight_trans_12  Days_since_enroll  clust
# clust
# 0             395.806108         1.163352        2202.517756    0.0
# 1             397.131075         1.157585        3017.675994    1.0
# 2             486.936481         1.490129        5757.966524    2.0
# 3             596.432396         1.784471        6173.950469    3.0

# %%
plt.style.use(['classic']) 
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
airlines.plot(x="Bonus_miles",y ="Bonus_trans",c=clf.labels_,kind="scatter",s=30 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
WCSS
# Out:
# [898.270582200747,
#  448.9989194445699,
#  331.43307973037713,
#  272.3925490904644,
#  241.0769941277309,
#  217.76316326756725,
#  200.25130180780113,
#  182.73222302568948,
#  171.31045530448526,
#  160.69139503105407]

# %%
import sklearn
sklearn.metrics.silhouette_score(airlines1,y_kmeans)
# Out:
# 0.37660565218548464

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

# %%
neighbors=NearestNeighbors(n_neighbors=8)
nbrs=neighbors.fit(airlines1)
distances, indices=nbrs.kneighbors(airlines1)

# %%
distances=np.sort(distances,axis=0)
distances=distances[:,1]
plt.plot(distances)

# %%
dbscan=DBSCAN(eps=0.475, min_samples=5)
dbscan.fit(airlines1)
# Out:
# DBSCAN(eps=0.475)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
c1=pd.DataFrame(dbscan.labels_,columns=['clusters'])

# %%
c1
# Out:
#       clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
df1=pd.concat([airlines,c1],axis=1)

# %%
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df1.plot(x="Balance",y="Days_since_enroll",c=dbscan.labels_,s=30,kind="scatter",cmap=plt.cm.copper_r)
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='Days_since_enroll'>

# %%
d1=dbscan.labels_

# %%
import sklearn
sklearn.metrics.silhouette_score(airlines1,d1)
# Out:
# 0.22565012869341308
